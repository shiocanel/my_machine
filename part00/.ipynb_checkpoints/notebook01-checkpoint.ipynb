# %%
import time

print("Downloading something...")
time.sleep(3)

dataset = [10, 20, 30, 40, 50]
print("Data succesfully loaded!")
# Out:
# ...
# Data succesfully loaded!

# %%
total = sum(dataset)
print(f"Sum of the dataset: {total}")
# Out:
# Sum of the dataset: 150

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- -----------
# annotated-types           0.8.0
# anyio                     4.14.2
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# asttokens                 3.0.2
# async-lru                 2.3.0
# attrs                     26.1.0
# babel                     2.18.0
# beautifulsoup4            4.15.0
# bleach                    6.4.0
# certifi                   2026.7.22
# cffi                      2.1.1
# charset-normalizer        3.4.9
# comm                      0.2.3
# debugpy                   1.8.21
# defusedxml                0.7.1
# distro                    1.9.0
# executing                 2.2.1
# fastjsonschema            2.22.1
# fqdn                      1.5.1
# h11                       0.16.0
# httpcore                  1.0.9
# httpx                     0.28.1
# idna                      3.18
# ipykernel                 7.3.0
# ...
